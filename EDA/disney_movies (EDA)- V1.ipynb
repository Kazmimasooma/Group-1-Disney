# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
for dirname, _, filenames in os.walk("Resources"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Resources\disney-characters.csv
# Resources\disney-directors.csv
# Resources\disney-voice-actors.csv
# Resources\disney_movies_total_gross.csv
# Resources\disney_revenue_1991-2016.csv
# Resources\walt_disney_movies.csv

# %%
df_character = pd.read_csv("Resources/disney-characters.csv")

df_revenue = pd.read_csv("Resources/disney_revenue_1991-2016.csv")

df_movie = pd.read_csv("Resources/disney_movies_total_gross.csv")

df_voice = pd.read_csv("Resources/disney-voice-actors.csv")

df_directors = pd.read_csv("Resources/disney-directors.csv")

# %% [markdown]
# # Exploring the Character Dataset

# %%
df_character.head()
# Out:
#                          movie_title       release_date        hero  \
# 0  \nSnow White and the Seven Dwarfs  December 21, 1937  Snow White
# 1                        \nPinocchio   February 7, 1940   Pinocchio
# 2                         \nFantasia  November 13, 1940         NaN
# 3                              Dumbo   October 23, 1941       Dumbo
# 4                            \nBambi    August 13, 1942       Bambi
#
#       villian                          song
# 0  Evil Queen  Some Day My Prince Will Come
# 1   Stromboli     When You Wish upon a Star
# 2   Chernabog                           NaN
# 3  Ringmaster                     Baby Mine
# 4      Hunter                Love Is a Song

# %% [markdown]
# ### Get rid of the \n character

# %%
df_character['movie_title'] = df_character['movie_title'].str.replace('\n','')

# %%
df_character.head(10)
# Out:
#                        movie_title        release_date          hero  \
# 0  Snow White and the Seven Dwarfs   December 21, 1937    Snow White
# 1                        Pinocchio    February 7, 1940     Pinocchio
# 2                         Fantasia   November 13, 1940           NaN
# 3                            Dumbo    October 23, 1941         Dumbo
# 4                            Bambi     August 13, 1942         Bambi
# 5                   Saludos Amigos    February 6, 1943   Donald Duck
# 6             The Three Caballeros    February 3, 1945   Donald Duck
# 7                  Make Mine Music      April 20, 1946           NaN
# 8               Fun and Fancy Free  September 27, 1947  Mickey Mouse
# 9                      Melody Time        May 27, 1948           NaN
#
#             villian                          song
# 0        Evil Queen  Some Day My Prince Will Come
# 1         Stromboli     When You Wish upon a Star
# 2         Chernabog                           NaN
# 3        Ringmaster                     Baby Mine
# 4            Hunter                Love Is a Song
# 5               NaN              Saludos Amigos\n
# 6               NaN                           NaN
# 7               NaN                           NaN
# 8  Willie the Giant                           NaN
# 9               NaN                   Little Toot

# %% [markdown]
# ### Get rid of NaN(Null) values

# %%
df_character.isnull().sum()
# Out:
# movie_title      0
# release_date     0
# hero             4
# villian         10
# song             9
# dtype: int64

# %%
df_character.fillna('NULL', inplace = True)

# %%
df_character[['movie_title','release_date','hero','villian','song']]
# Out:
#                                movie_title        release_date  \
# 0          Snow White and the Seven Dwarfs   December 21, 1937
# 1                                Pinocchio    February 7, 1940
# 2                                 Fantasia   November 13, 1940
# 3                                    Dumbo    October 23, 1941
# 4                                    Bambi     August 13, 1942
# 5                           Saludos Amigos    February 6, 1943
# 6                     The Three Caballeros    February 3, 1945
# 7                          Make Mine Music      April 20, 1946
# 8                       Fun and Fancy Free  September 27, 1947
# 9                              Melody Time        May 27, 1948
# 24                       Taran                           Horned King
# 25                       Basil                     Professor Ratigan
# 26                      Oliver                                 Sykes
# 27                       Ariel                                Ursula
# 28     Bernard and Miss Bianca                   Percival C. McLeach
# 29                       Belle                                Gaston
# 30                     Aladdin                                 Jafar
# 31                       Simba                                  Scar
# 32                  Pocahontas                    Governor Ratcliffe
# 33                   Quasimodo                         Claude Frollo
# 34                    Hercules                                 Hades
# 35                       Mulan                               Shan Yu
# 36                      Tarzan                               Clayton
# 37                        NULL                                  NULL
# 38                      Aladar                                  Kron
# 39                       Kuzco                                  Yzma
# 40                 Milo Thatch                      Commander Rourke
# 41             Lilo and Stitch                                  NULL
# 42                 Jim Hawkins                           John Silver
# 43                       Kenai                                Denahi
# 44                      Maggie                          Alameda Slim
# 45                   Ace Cluck                             Foxy Loxy
# 46                       Lewis                                 Doris
# 47                        Bolt                            Dr. Calico
# 48                       Tiana                          Dr. Facilier
# 49                    Rapunzel                         Mother Gothel
# 50             Winnie the Pooh                                  NULL
# 51                       Ralph                                 Turbo
# 52                        Elsa                           Prince Hans
# 53                 Hiro Hamada                   Professor Callaghan
# 54                  Judy Hopps                                  NULL
# 55                       Moana                                  NULL
#
#                                   song
# 0         Some Day My Prince Will Come
# 1            When You Wish upon a Star
# 2                                 NULL
# 3                            Baby Mine
# 4                       Love Is a Song
# 5                     Saludos Amigos\n
# 6                                 NULL
# 7                                 NULL
# 8                                 NULL
# 9                          Little Toot
# 10                    The Merrily Song
# 11                 Bibbidi-Bobbidi-Boo
# 12                 The Unbirthday Song
# 13                        You Can Fly!
# 14                         Bella Notte
# 15                   Once Upon a Dream
# 16                      Cruella De Vil
# 17                   Higitus Figitus\n
# 18              The Bare Necessities\n
# 19         Ev'rybody Wants to Be a Cat
# 20                         Oo De Lally
# 21                     Winnie the Pooh
# 22                         The Journey
# 23                     Best of Friends
# 24                                NULL
# 25  The World's Greatest Criminal Mind
# 26   Once Upon a Time in New York City
# 27                       Under the Sea
# 28                                  \n
# 29                        Be Our Guest
# 30                   A Whole New World
# 31                      Circle of Life
# 32                  Colors of the Wind
# 33               God Help the Outcasts
# 34                     Go the Distance
# 35        I'll Make a Man Out of You\n
# 36               You'll Be in My Heart
# 37                                NULL
# 38                                NULL
# 39            My Funny Friend and Me\n
# 40           Where the Dream Takes You
# 41                   He Mele No Lilo\n
# 42                    I'm Still Here\n
# 43                Look Through My Eyes
# 44                                NULL
# 45                                NULL
# 46                      Little Wonders
# 47                I Thought I Lost You
# 48                        Almost There
# 49                     I See the Light
# 50                   Winnie the Pooh\n
# 51                          Sugar Rush
# 52                         Let It Go\n
# 53                           Immortals
# 54                      Try Everything
# 55                   How Far I'll Go\n

# %%
df_character.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   movie_title   56 non-null     object
#  1   release_date  56 non-null     object
#  2   hero          56 non-null     object
#  3   villian       56 non-null     object
#  4   song          56 non-null     object
# dtypes: object(5)
# memory usage: 2.3+ KB

# %%
df_character.duplicated(subset=['release_date'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# dtype: bool

# %% [markdown]
# # Exploring the Revenue Dataset

# %%
df_revenue.head()
# Out:
#    Year  Studio Entertainment[NI 1]  Disney Consumer Products[NI 2]  \
# 0  1991                      2593.0                           724.0
# 1  1992                      3115.0                          1081.0
# 2  1993                      3673.4                          1415.1
# 3  1994                      4793.0                          1798.2
# 4  1995                      6001.5                          2150.0
#
#    Disney Interactive[NI 3][Rev 1]  Walt Disney Parks and Resorts  \
# 0                              NaN                         2794.0
# 1                              NaN                         3306.0
# 2                              NaN                         3440.7
# 3                              NaN                         3463.6
# 4                              NaN                         3959.8
#
#    Disney Media Networks  Total
# 0                    NaN   6111
# 1                    NaN   7502
# 2                    NaN   8529
# 3                  359.0  10414
# 4                  414.0  12525

# %% [markdown]
# ### Simplifying the columns

# %%
df1 =df_revenue.rename(columns={'Studio Entertainment[NI 1]':'StudioEntertainment','Disney Consumer Products[NI 2]':'DisneyConsumerProducts','Disney Interactive[NI 3][Rev 1]':'DisneyInteractive','Walt Disney Parks and Resorts':'WaltDisneyParks','Disney Media Networks':'DisneyMediaNetworks'})

# %%
df1.describe()
# Out:
#               Year  StudioEntertainment  DisneyConsumerProducts  \
# count    26.000000            25.000000               24.000000
# mean   2003.500000          6445.036000             2591.054167
# std       7.648529          1570.276711              877.112322
# min    1991.000000          2593.000000              724.000000
# 25%    1997.250000          5994.000000             2182.250000
# 50%    2003.500000          6701.000000             2475.500000
# 75%    2009.750000          7364.000000             3085.000000
# max    2016.000000          9441.000000             4499.000000
#
#        DisneyInteractive  WaltDisneyParks  DisneyMediaNetworks         Total
# count          12.000000        26.000000            23.000000     26.000000
# mean          713.666667      8512.619231         12877.695652  29459.692308
# std           386.480938      4253.949784          6736.879986  13846.671536
# min           174.000000      2794.000000           359.000000   6111.000000
# 25%           341.000000      5143.500000          8540.500000  22598.750000
# 50%           740.000000      7276.500000         13207.000000  28906.500000
# 75%          1002.500000     11318.250000         17938.000000  38008.000000
# max          1299.000000     16974.000000         23689.000000  55632.000000

# %%
df1.isnull().sum()
# Out:
# Year                       0
# StudioEntertainment        1
# DisneyConsumerProducts     2
# DisneyInteractive         14
# WaltDisneyParks            0
# DisneyMediaNetworks        3
# Total                      0
# dtype: int64

# %%
df1.info
# Out:
# <bound method DataFrame.info of     Year  StudioEntertainment  DisneyConsumerProducts  DisneyInteractive  \
# 0   1991               2593.0                   724.0                NaN
# 1   1992               3115.0                  1081.0                NaN
# 2   1993               3673.4                  1415.1                NaN
# 3   1994               4793.0                  1798.2                NaN
# 4   1995               6001.5                  2150.0                NaN
# 5   1996                  NaN                     NaN                NaN
# 22  2013               5979.0                  3555.0             1064.0
# 23  2014               7278.0                  3985.0             1299.0
# 24  2015               7366.0                  4499.0             1174.0
# 25  2016               9441.0                     0.0                0.0
#
#     WaltDisneyParks  DisneyMediaNetworks  Total
# 0            2794.0                  0.0   6111
# 1            3306.0                  0.0   7502
# 2            3440.7                  0.0   8529
# 3            3463.6                359.0  10414
# 4            3959.8                414.0  12525
# 5            4502.0               4142.0  18739
# 6            5014.0               6522.0  22473
# 7            5532.0               7142.0  22976
# 8            6106.0               7512.0  23402
# 9            6803.0               9615.0  25402
# 10           6009.0               9569.0  25790
# 11           6691.0               9733.0  25360
# 12           6412.0              10941.0  27061
# 13           7750.0              11778.0  30752
# 14           9023.0              13207.0  31944
# 15           9925.0              14368.0  34285
# 16          10626.0              15046.0  35510
# 17          11504.0              15857.0  37843
# 18          10667.0              16209.0  36149
# 19          10761.0              17162.0  38063
# 20          11797.0              18714.0  40893
# 21          12920.0              19436.0  42278
# 22          14087.0              20356.0  45041
# 23          15099.0              21152.0  48813
# 24          16162.0              23264.0  52465
# 25          16974.0              23689.0  55632

# %%
sns.lineplot(x='Year',y='StudioEntertainment',linewidth = 4,color = 'green',linestyle='dashed',data = df1).set(title='Studio Entertainment Revenue')
# Out:
# [Text(0.5, 1.0, 'Studio Entertainment Revenue')]

# %%
#df1[['DisneyConsumerProducts','Year']]

sns.lineplot(x='Year',y='DisneyConsumerProducts',linewidth = 4,color = 'purple',linestyle='dashed',data = df1).set(title='Disney Consumer Products Revenue')
# Out:
# [Text(0.5, 1.0, 'Disney Consumer Products Revenue')]

# %%
sns.lineplot(x='Year',y='DisneyInteractive',linewidth = 4,color = 'red',linestyle='dashed',data = df1).set(title='Disney Interactive Revenue')
# Out:
# [Text(0.5, 1.0, 'Disney Interactive Revenue')]

# %%
sns.lineplot(x='Year',y='WaltDisneyParks',linewidth = 4,color = 'blue',linestyle='dashed',data = df1).set(title='Walt Disney Parks Revenue')
# Out:
# [Text(0.5, 1.0, 'Walt Disney Parks Revenue')]

# %%
df1['DisneyMediaNetworks'] = df1['DisneyMediaNetworks'].fillna(0)

# %%
df1[['DisneyMediaNetworks','Year']]
# Out:
#     DisneyMediaNetworks  Year
# 0                   0.0  1991
# 1                   0.0  1992
# 2                   0.0  1993
# 3                 359.0  1994
# 4                 414.0  1995
# 5                4142.0  1996
# 6                6522.0  1997
# 7                7142.0  1998
# 8                7512.0  1999
# 9                9615.0  2000
# 10               9569.0  2001
# 11               9733.0  2002
# 12              10941.0  2003
# 13              11778.0  2004
# 14              13207.0  2005
# 15              14368.0  2006
# 16              15046.0  2007
# 17              15857.0  2008
# 18              16209.0  2009
# 19              17162.0  2010
# 20              18714.0  2011
# 21              19436.0  2012
# 22              20356.0  2013
# 23              21152.0  2014
# 24              23264.0  2015
# 25              23689.0  2016

# %%
sns.lineplot(x='Year',y='DisneyMediaNetworks',linewidth = 4,color = 'orange',linestyle='dashed',data = df1).set(title='DisneyMediaNetworks')
# Out:
# [Text(0.5, 1.0, 'DisneyMediaNetworks')]

# %% [markdown]
# # Exploring the Disney Movie Total Gross dataset

# %%
df_movie.head()
# Out:
#                        movie_title  release_date      genre MPAA_rating  \
# 0  Snow White and the Seven Dwarfs  Dec 21, 1937    Musical           G
# 1                        Pinocchio   Feb 9, 1940  Adventure           G
# 2                         Fantasia  Nov 13, 1940    Musical           G
# 3                Song of the South  Nov 12, 1946  Adventure           G
# 4                       Cinderella  Feb 15, 1950      Drama           G
#
#     total_gross inflation_adjusted_gross
# 0  $184,925,485           $5,228,953,251
# 1   $84,300,000           $2,188,229,052
# 2   $83,320,000           $2,187,090,808
# 3   $65,000,000           $1,078,510,579
# 4   $85,000,000             $920,608,730

# %%
df_movie.isnull().sum()
# Out:
# movie_title                  0
# release_date                 0
# genre                       17
# MPAA_rating                 56
# total_gross                  0
# inflation_adjusted_gross     0
# dtype: int64

# %%
df_movie.fillna('NULL', inplace = True)

# %%
sum(df_movie.duplicated())
# Out:
# 0

# %%
import datetime
df_movie['release_date'] = pd.to_datetime(df_movie['release_date'])
df_movie['release_date'].head()
# Out:
# 0   1937-12-21
# 1   1940-02-09
# 2   1940-11-13
# 3   1946-11-12
# 4   1950-02-15
# Name: release_date, dtype: datetime64[ns]

# %%
df_movie.drop(['MPAA_rating','inflation_adjusted_gross',],axis=1,inplace = True)
print('After Removing Unused Columns(Rows,Columns) :',df_movie.shape)
# Out:
# After Removing Unused Columns(Rows,Columns) : (579, 4)

# %%
# Checking for zero values
print('Rows with Zero Values in the Total Gross Column',df_movie[(df_movie['total_gross']==0)].shape[0])
# Out:
# Rows with Zero Values in the Total Gross Column 0

# %% [markdown]
# ### Movie count per year

# %%
# make group for each year and count the number of movies in each year
data = df_movie.groupby('release_date').count()['movie_title']
print(data.tail())
#Make a group of the data according to their release year and count total number 
df_movie.groupby('release_date').count()['movie_title'].plot()

#set the figure size and labels
sns.set(rc={'figure.figsize':(10,5)})
plt.title('Year vs Number of Movies',fontsize = 14)
plt.xlabel('Release Year', fontsize = 13)
plt.ylabel('Number of Movies', fontsize = 13)
sns.set_style('whitegrid')
# Out:
# release_date
# 2016-09-02    1
# 2016-09-23    1
# 2016-11-04    1
# 2016-11-23    1
# 2016-12-16    1
# Name: movie_title, dtype: int64

# %%
df_movie['total_gross'] = df_movie['total_gross'].str.replace(',','')
df_movie['total_gross'] = df_movie['total_gross'].str.replace('$','')
df_movie['total_gross'] = df_movie['total_gross'].astype(int)
# Out:
# C:\Users\masoomakazmi\.conda\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %% [markdown]
# ### Highest Grossing and Lowest Grossing Movie

# %%
def find_minmax(x):
    min_index = df_movie[x].idxmin()
    high_index = df_movie[x].idxmax()
    high = pd.DataFrame(df_movie.loc[high_index,:])
    low = pd.DataFrame(df_movie.loc[min_index,:])
    
    print('Movie Which has the Highest '+ x +':',df_movie['movie_title'][high_index])
    print('Movie Which has the Lowest '+ x +':',df_movie['movie_title'][min_index])
    return pd.concat([high,low],axis =1)

find_minmax('total_gross')
# Out:
# Movie Which has the Highest total_gross: Star Wars Ep. VII: The Force Awakens
# Movie Which has the Lowest total_gross: The Many Adventures of Winnie the Pooh
#                                                564  \
# movie_title   Star Wars Ep. VII: The Force Awakens
# release_date                   2015-12-18 00:00:00
# genre                                    Adventure
# total_gross                              936662225
#
#                                                  20
# movie_title   The Many Adventures of Winnie the Pooh
# release_date                     1977-03-11 00:00:00
# genre                                           NULL
# total_gross                                        0

# %% [markdown]
# ### Top 10 Grossing Movies

# %%
info = pd.DataFrame(df_movie['total_gross'].sort_values(ascending= False))
info['movie_title'] = df_movie['movie_title']
data = list(map(str,(info['movie_title'])))
x = list(data[:10])
y = list(info['total_gross'][:10])

ax = sns.pointplot(x=y,y=x)

sns.set(rc={'figure.figsize':(10,5)})
ax.set_title('Top 10 Movies',fontsize = 25)
ax.set_xlabel('Total Gross',fontsize= 15)
sns.set_style('darkgrid')

# %% [markdown]
# ## Statistics by months

# %%
# extract the month number from the release date
month_release = df_movie['release_date'].dt.month

#Count the movies in each month using value_counts
number_of_releases = month_release.value_counts().sort_index()
months =['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
number_of_releases = pd.DataFrame(number_of_releases)
number_of_releases['month'] = months

#change the column name of the new dataframe
number_of_releases.rename(columns = {'release_date':'number_of_releases'},inplace = True)

# %% [markdown]
# ### Movie releases by months (1937-2016)

# %%
# plot the bar graph
number_of_releases.plot(x='month', kind='bar',fontsize = 15, figsize=(15,10))

#set the labels and titles 
plt.title('Months vs Number of Movie Releases', fontsize = 25)
plt.xlabel('Month', fontsize=15)
plt.ylabel('Number of movie releases', fontsize =15)
sns.set_style('darkgrid')

# %% [markdown]
# ### Average gross by month (1937-2016)

# %%
month_release = pd.DataFrame(month_release)
month_release.rename(columns= {'release_date':'release_month'},inplace = True)

month_release['total_gross'] = df_movie['total_gross']
 

mean_revenue = month_release.groupby('release_month').mean()
mean_revenue['month'] = months

mean_revenue.plot(x = 'month', kind='bar', figsize = (15,10),fontsize = 15)

plt.title('Average Gross by month (1937 -2016)',fontsize = 25)
plt.xlabel('Month', fontsize = 15)
plt.ylabel('Average Gross', fontsize = 15)
sns.set_style('darkgrid')

# %% [markdown]
# ### Genre Statistics

# %%
# make a function will split the string and return the count of each genre
def count_genre(x):
    # concatenate all the rows of the genre
    data_plot = df_movie[x].str.cat(sep= '|')
    data = pd.Series(data_plot.split('|'))
    info = data.value_counts(ascending= False)
    return info

total_genre_movies = count_genre('genre')
total_genre_movies.plot(kind='barh',figsize=(20,10),fontsize=12, colormap = 'tab20c')

plt.title('Genre Statistics', fontsize = 15)
plt.xlabel('Number of Movies', fontsize = 15)
plt.ylabel('Genres', fontsize = 15)
sns.set_style('whitegrid')

# %%
i = 0
genre_count = []
for genre in total_genre_movies.index:
    genre_count.append([genre,total_genre_movies[i]])
    i = i+1
    
plt.rc('font', weight = 'bold')
f, ax = plt.subplots(figsize = (5,5))
genre_count.sort(key = lambda x:x[1], reverse= True)
labels, sizes = zip(*genre_count)
labels_selected = [n if v > sum(sizes) * 0.01 else '' for n,v in genre_count]
ax.pie(sizes, labels = labels_selected,autopct = lambda x:'{:2.0f}%'.format(x) if x > 1 else '',
      shadow = False, startangle= 0)
ax.axis('equal')
plt.tight_layout()

# %% [markdown]
# # Exploring Voice actors

# %%
df_voice.head()
# Out:
#         character      voice-actor                        movie
# 0    Abby Mallard      Joan Cusack               Chicken Little
# 1  Abigail Gabble     Monica Evans               The Aristocats
# 2        Abis Mal  Jason Alexander          The Return of Jafar
# 3             Abu     Frank Welker                      Aladdin
# 4        Achilles             None  The Hunchback of Notre Dame

# %%
df_voice.isnull().sum()
# Out:
# character      0
# voice-actor    0
# movie          0
# dtype: int64

# %%
df_voice['voice-actor'].value_counts()
# Out:
# None                                 53
# Frank Welker                         24
# Jim Cummings                         17
# Corey Burton                          8
# J. Pat O'Malley                       8
#                                      ..
# Zachary Levi                          1
# Leo De Lyon                           1
# Stan Alexander; Sterling Holloway     1
# Jason Marin                           1
# Suzanne Pleshette                     1
# Name: voice-actor, Length: 656, dtype: int64

# %%
#Getting rid of None values
df_voice = df_voice.replace(to_replace='None', value=np.nan).dropna()

# %%
#Since the same voice actor can perform in multiple movies, we have 227 duplicates
sum(df_voice['voice-actor'].duplicated())
# Out:
# 227

# %%
df_voice['voice-actor'].value_counts()[0:10].plot(kind='bar',figsize=(20,10))
plt.xlabel('Voice Actor',fontsize = 30)
plt.ylabel('Amount of Movies',fontsize = 20)
plt.title('Top 10 Voice Actors',fontsize = 30)
sns.set_style('darkgrid')

# %% [markdown]
# # Exploring Directors

# %%
df_directors.head()
# Out:
#                               name        director
# 0  Snow White and the Seven Dwarfs      David Hand
# 1                        Pinocchio  Ben Sharpsteen
# 2                         Fantasia    full credits
# 3                            Dumbo  Ben Sharpsteen
# 4                            Bambi      David Hand

# %%
df_directors.isnull().sum()
# Out:
# name        0
# director    0
# dtype: int64

# %%
df_directors['director'].value_counts()
# Out:
# Ron Clements           7
# Wolfgang Reitherman    7
# Jack Kinney            4
# Gary Trousdale         3
# Clyde Geronimi         3
# Stephen J. Anderson    2
# Mark Dindal            2
# Chris Buck             2
# Ben Sharpsteen         2
# Mike Gabriel           2
# David Hand             2
# Hamilton Luske         2
# full credits           2
# Ted Berman             1
# Robert Walker          1
# Don Hall               1
# Rich Moore             1
# Nathan Greno           1
# Chris Williams         1
# Will Finn              1
# Chris Sanders          1
# George Scribner        1
# Norman Ferguson        1
# Ralph Zondag           1
# Wilfred Jackson        1
# Barry Cook             1
# Roger Allers           1
# Art Stevens            1
# Byron Howard           1
# Name: director, dtype: int64

# %%
df_directors['director'].value_counts()[0:10].plot(kind='bar',figsize=(20,10))
plt.xlabel('Director',fontsize = 30)
plt.ylabel('Amount of Movies',fontsize = 20)
plt.title('Top 10 Directors',fontsize = 30)
sns.set_style('darkgrid')
