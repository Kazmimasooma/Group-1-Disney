# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import tensorflow as tf

# Import our input dataset
movie_df = pd.read_csv('resource/walt_disney_movies.csv')
movie_df.head()
# Out:
#    Unnamed: 0                            title       Production company  \
# 0           0          Academy Award Review of  Walt Disney Productions
# 1           1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2           2                        Pinocchio  Walt Disney Productions
# 3           3                         Fantasia  Walt Disney Productions
# 4           4             The Reluctant Dragon  Walt Disney Productions
#
#          Country Language  Running time     Budget    Box office Release date  \
# 0  United States  English          41.0        NaN  4.547200e+01   1937-05-19
# 1  United States  English          83.0  1490000.0  4.180000e+08   1937-12-21
# 2  United States  English          88.0  2600000.0  1.640000e+08   1940-02-07
# 3  United States  English         126.0  2280000.0  8.330000e+07   1940-11-13
# 4  United States  English          74.0   600000.0  9.600000e+05   1941-06-20
#
#    imdb  ...  rotten_tomatoes  \
# ...

# %%
movie_df.tail()
# Out:
#      Unnamed: 0                title  \
# 439         439   The Little Mermaid
# 440         440    Peter Pan & Wendy
# 441         441           Home Alone
# 442         442               Shrunk
# 443         443  Night at the Museum
#
#                                     Production company        Country  \
# 439  ['Walt Disney Pictures', 'Lucamar Productions'...  United States
# 440  ['Walt Disney Pictures', 'Whitaker Entertainme...  United States
# 441  ['20th Century Studios', 'Hutch Parker Enterta...  United States
# 442       ['Walt Disney Pictures', 'Mandeville Films']  United States
# 443  ['21 Laps Entertainment', 'Ingenious Film Part...  United States
#
#     Language  Running time       Budget    Box office Release date  imdb  ...  \
# 439  English           NaN          NaN           NaN          NaN   7.6  ...
# 440  English           NaN          NaN           NaN          NaN   NaN  ...
# 441  English           NaN          NaN           NaN          NaN   7.6  ...
# ...

# %%
movie_df.keys()
# Out:
# Index(['Unnamed: 0', 'title', 'Production company', 'Country', 'Language',
#        'Running time', 'Budget', 'Box office', 'Release date', 'imdb',
#        'metascore', 'rotten_tomatoes', 'Directed by', 'Produced by',
#        'Based on', 'Starring', 'Music by', 'Distributed by', 'Cinematography',
#        'Edited by', 'Screenplay by'],
#       dtype='object')

# %%
clean_movie_df = movie_df[['title','Release date','imdb', 'metascore', 'rotten_tomatoes']]

# %%
clean_movie_df.head()
# Out:
#                              title Release date  imdb  metascore  \
# 0          Academy Award Review of   1937-05-19   7.2        NaN
# 1  Snow White and the Seven Dwarfs   1937-12-21   7.6       95.0
# 2                        Pinocchio   1940-02-07   7.4       99.0
# 3                         Fantasia   1940-11-13   7.7       96.0
# 4             The Reluctant Dragon   1941-06-20   6.9        NaN
#
#   rotten_tomatoes
# 0             NaN
# 1             NaN
# 2             73%
# 3             95%
# 4             68%

# %%
clean_movie_df.isnull().sum()
# Out:
# title                0
# Release date         9
# imdb                20
# metascore          151
# rotten_tomatoes     53
# dtype: int64

# %%
clean_movie_df.isna().any()[lambda x: x]
# Out:
# Release date       True
# imdb               True
# metascore          True
# rotten_tomatoes    True
# dtype: bool

# %%
clean_movie_df[clean_movie_df.isnull().any(axis=1)]
# Out:
#                                title Release date  imdb  metascore  \
# 0            Academy Award Review of   1937-05-19   7.2        NaN
# 1    Snow White and the Seven Dwarfs   1937-12-21   7.6       95.0
# 4               The Reluctant Dragon   1941-06-20   6.9        NaN
# 7                     Saludos Amigos   1942-08-24   6.1       60.0
# 8          Victory Through Air Power   1943-07-17   6.5        NaN
# ..                               ...          ...   ...        ...
# 439               The Little Mermaid          NaN   7.6       88.0
# 440                Peter Pan & Wendy          NaN   NaN        NaN
# 441                       Home Alone          NaN   7.6       63.0
# 442                           Shrunk          NaN   NaN        NaN
# 443              Night at the Museum          NaN   6.4       48.0
#
#     rotten_tomatoes
# 0               NaN
# 1               NaN
# 4               68%
# 7               NaN
# 8               54%
# ..              ...
# ...
